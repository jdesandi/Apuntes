# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !dir
# Out:
#  El volumen de la unidad C es OS
#  El n£mero de serie del volumen es: 7C08-4B63
#
#  Directorio de C:\Users\jdesa
#
# 20/03/2019  07:33 p. m.    <DIR>          .
# 20/03/2019  07:33 p. m.    <DIR>          ..
# 28/01/2019  07:22 p. m.                37 .gitconfig
# 20/03/2019  07:33 p. m.    <DIR>          .ipynb_checkpoints
# 16/01/2019  07:26 p. m.    <DIR>          .ipython
# 23/01/2019  01:08 p. m.    <DIR>          .jupyter
# 09/02/2019  11:57 a. m.    <DIR>          .matplotlib
# 17/02/2019  06:05 p. m.    <DIR>          .Origin
# 17/02/2019  06:05 p. m.    <DIR>          .QtWebEngineProcess
# 09/02/2019  11:57 a. m.    <DIR>          .spyder-py3
# 23/01/2019  07:14 p. m.         1,861,069 Ciclos.ipynb
# 03/03/2019  07:21 p. m.    <DIR>          Documents
# 05/12/2018  07:24 p. m.    <DIR>          FoundryAnalytics
# 23/01/2019  08:23 p. m.             5,966 Funciones.ipynb
# 20/03/2019  07:26 p. m.    <DIR>          OneDrive
# ...

# %%
data= pd.read_excel("osv_acumulado_2013-2019.xlsx",skiprows=3,skipfooter=2)
data
# Out:
#                    MES  Pruebas aplicadas  Conductores retenidos  \
# 0   Noviembre  (15-30)               6659                    142
# 1            Diciembre              12332                    220
# 2          Enero  2014              16944                    258
# 3              Febrero              15850                    343
# 4                Marzo              16123                    380
# 5                Abril              15714                    284
# 6                 Mayo              14774                    287
# 7                Junio              12704                    288
# 8                Julio              15343                    326
# 9               Agosto              18762                    401
# 10          Septiembre              11699                    264
# 11             Octubre              16407                    398
# 12           Noviembre              16281                    331
# ...

# %%
data.tail()
# Out:
#                   MES  Pruebas aplicadas  Conductores retenidos  \
# 61          Diciembre           148410.0                  864.0
# 62        Enero  2019            89032.0                  407.0
# 63            Febrero           151658.0                  907.0
# 64          Acumulado          2113245.0                24840.0
# 65  Fuente: Ce.Co.Vi.                NaN                    NaN
#
#     Sanción económica  Total pruebas positivas %\npositivas/a plicadas  \
# 61              513.0                   1377.0                   0.93%
# 62              216.0                    623.0                   0.70%
# 63              477.0                   1384.0                   0.91%
# 64            15214.0                  40054.0                   1.90%
# 65                NaN                      NaN                     NaN
#
#     Días  con Operativo  Promedio diario positivas
# 61                 31.0                      44.42
# ...

# %%
data.head()
# Out:
#                   MES  Pruebas aplicadas  Conductores retenidos  \
# 0  Noviembre  (15-30)               6659                    142
# 1           Diciembre              12332                    220
# 2         Enero  2014              16944                    258
# 3             Febrero              15850                    343
# 4               Marzo              16123                    380
#
#    Sanción económica  Total pruebas positivas %\npositivas/a plicadas  \
# 0                 59                      201                   3.02%
# 1                 77                      297                   2.41%
# 2                110                      368                   2.17%
# 3                141                      484                   3.05%
# 4                214                      594                   3.68%
#
#    Días  con Operativo  Promedio diario positivas
# 0                   10                      20.10
# 1                   16                      18.56
# ...

# %%
data["Pruebas aplicadas"]
# Out:
# 0       6659
# 1      12332
# 2      16944
# 3      15850
# 4      16123
# 5      15714
# 6      14774
# 7      12704
# 8      15343
# 9      18762
# 10     11699
# 11     16407
# 12     16281
# 13     19965
# 14     21567
# 15     15083
# 16     16620
# 17     19087
# 18     17640
# 19     17556
# 20     21242
# 21     19570
# 22     21064
# 23     21322
# 24     21671
# 25     43666
# 26     46442
# 27     36626
# 28     22999
# 29     25739
#        ...
# 34     31385
# 35     31182
# 36     30572
# 37     63943
# 38     53312
# 39     41110
# 40     39320
# 41     35619
# 42     36959
# 43     38384
# 44     34879
# 45     43992
# 46     35725
# 47     40166
# 48     39380
# 49     54153
# 50     46770
# 51     35659
# 52     37769
# 53     39912
# 54     39019
# 55     36684
# 56     34049
# 57     35848
# 58     31885
# 59     31063
# 60     27560
# 61    148410
# 62     89032
# 63    151658
# Name: Pruebas aplicadas, Length: 64, dtype: int64

# %%
Pa=sum(data["Pruebas aplicadas"])
Pa
# Out:
# 2113245

# %%
Cr=data["Conductores retenidos"].sum()
Cr
# Out:
# 24840

# %%
Prob=Cr/Pa
Prob*100
# Out:
# 1.1754434530780862

# %%
data.describe()
# Out:
#        Pruebas aplicadas  Conductores retenidos  Sanción económica  \
# count          64.000000              64.000000          64.000000
# mean        33019.453125             388.125000         237.718750
# std         25537.965370             122.652367          77.747754
# min          6659.000000             142.000000          59.000000
# 25%         17619.000000             323.750000         197.500000
# 50%         29066.000000             376.000000         230.000000
# 75%         38542.750000             429.750000         275.500000
# max        151658.000000             907.000000         513.000000
#
#        Total pruebas positivas  Días  con Operativo  Promedio diario positivas
# count                 64.00000            64.000000                  64.000000
# mean                 625.84375            24.843750                  26.464375
# std                  196.03751             6.735876                   8.762802
# ...
